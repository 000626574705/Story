# %% [markdown]
# <a href="https://colab.research.google.com/github/000626574705/python/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1 solution-it is often necessary to handle exceptional or unexpected situations that may arise during the execution of your code. Exception handling allows you to gracefully manage and recover from such situations, ensuring that your program doesn't crash or produce incorrect results.
# Several of benefits of custom exception:-
# 1.Standardized error handling
# 2.Categorization and specificity
# 3.Custom error messages and data
# 4.control flow and exception handling.

# %%
#Q2 solution-

def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

# Print the exception hierarchy starting from the base Exception class
print_exception_hierarchy(Exception)
# Out:
# Exception
#     TypeError
#         MultipartConversionError
#         FloatOperation
#         UFuncTypeError
#             UFuncTypeError
#             UFuncTypeError
#             UFuncTypeError
#                 UFuncTypeError
#                 UFuncTypeError
#         ConversionError
#     StopAsyncIteration
#     StopIteration
#     ImportError
#         ModuleNotFoundError
#             PackageNotFoundError
#         ZipImportError
#     OSError
#         ConnectionError
#             BrokenPipeError
#             ConnectionAbortedError
#             ConnectionRefusedError
#             ConnectionResetError
#                 RemoteDisconnected
#         BlockingIOError
#         ChildProcessError
#         FileExistsError
#         FileNotFoundError
#             ExecutableNotFoundError
#         IsADirectoryError
#         NotADirectoryError
#         InterruptedError
#             InterruptedSystemCall
#         PermissionError
#         ProcessLookupError
# ...

# %%
#Q3 solution -The errors defined under the ArithmeticError class are as follows:

# FloatingPointError: This exception is raised when a floating-point operation fails.
# OverflowError: This exception is raised when the result of an arithmetic operation is too large to be expressed within the available numeric range.
# ZeroDivisionError: This exception is raised when attempting to divide a number by zero.

#example 1
try:
  a=10/0
except ArithmeticError as e:
  print(e)

# example 2
try:
  result = 10**10000
  print(result)
except ValueError as e:
  print(e)
# Out:
# division by zero
# Exceeds the limit (4300) for integer string conversion; use sys.set_int_max_str_digits() to increase the limit

# %%
#Q4 These exceptions allow you to handle lookup-related errors in a specific and controlled manner.
# By catching these exceptions, you can handle scenarios where certain lookup operations fail and take appropriate actions in response to the error.

# these lookuperror is base exception for various error like IndexErrpr ,KeyError,ModuleNotFoundError, Attribute

# Example

try:
    my_list = [1, 2, 3]
    print(my_list[5])  # Accessing an index that doesn't exist
except IndexError:
    print("An IndexError occurred: Index is out of range.")
# Out:
# An IndexError occurred: Index is out of range.

# %% [markdown]
# Q5 ImportError -The ImportError is a common exception that occurs when an import statement fails to find and load the specified module. This can happen due to various reasons, such as the module not being installed or not being available in the current environment.
#
#
# ModuleNotFoundError-The ModuleNotFoundError exception is specifically raised when a module cannot be found or imported. It typically occurs when the specified module is not installed or not available in the current Python environment.

# %% [markdown]
# Q6 solution - Best practices for Exception Handling
#
# 1.Be specific with exception handling
# 2.Keep exception handling code focused.
# 3.Use multiple 'except' blocks.
# 4.use 'finally' for  cleanup.
# 5.Avoid silent failures
# 6.Don't catch exception you can't handle.
# 7.Use exception chaining
# 8.Keep error messages informative.
# 9.Document exception behaiviour.
