# %% [markdown]
# <a href="https://colab.research.google.com/github/000626574705/python/blob/main/Pandas5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd

# %%
data = {
    "a":[1,2,3,4],
    "b":[4,5,6,7],
    "c":["sudh","ani","dgh","nam"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    a  b     c
# 0  1  4  sudh
# 1  2  5   ani
# 2  3  6   dgh
# 3  4  7   nam

# %%
df.set_index('a',inplace=True)  #to set a col as index

# %%
data = {
    "a":[1,2,3,4],
    "b":[4,5,6,7],
    "c":["sudh","ani","dgh","nam"]
}
ds1=pd.DataFrame(data ,index=['a','b','c','d'])

# %%
ds1
# Out:
#    a  b     c
# a  1  4  sudh
# b  2  5   ani
# c  3  6   dgh
# d  4  7   nam

# %%
ds1.reindex(['b','d','c','a'])    #to reindexing on the basis of following order
# Out:
#    a  b     c
# b  2  5   ani
# d  4  7   nam
# c  3  6   dgh
# a  1  4  sudh

# %%
ds1
# Out:
#    a  b     c
# a  1  4  sudh
# b  2  5   ani
# c  3  6   dgh
# d  4  7   nam

# %%
for i,j in ds1.iterrows():
  print(i,j)        #used to iterate row by row return (rowindex) columnvise element
# Out:
# a a       1
# b       4
# c    sudh
# Name: a, dtype: object
# b a      2
# b      5
# c    ani
# Name: b, dtype: object
# c a      3
# b      6
# c    dgh
# Name: c, dtype: object
# d a      4
# b      7
# c    nam
# Name: d, dtype: object

# %%
ds1
# Out:
#    a  b     c
# a  1  4  sudh
# b  2  5   ani
# c  3  6   dgh
# d  4  7   nam

# %%
for i,j in ds1.iteritems():    #gives data columnwise
  print(i,j)
# Out:
# a a    1
# b    2
# c    3
# d    4
# Name: a, dtype: int64
# b a    4
# b    5
# c    6
# d    7
# Name: b, dtype: int64
# c a    sudh
# b     ani
# c     dgh
# d     nam
# Name: c, dtype: object
# <ipython-input-81-21625e30ade7>:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i,j in ds1.iteritems():    #gives data columnwise

# %%
ds1
# Out:
#    a  b     c
# a  1  4  sudh
# b  2  5   ani
# c  3  6   dgh
# d  4  7   nam

# %%
[i for i in ds1['a']]   #gives data of a column in the form of list
# Out:
# [1, 2, 3, 4]

# %%
 ds1
# Out:
#    a  b     c
# a  1  4  sudh
# b  2  5   ani
# c  3  6   dgh
# d  4  7   nam

# %%
def test(c):
  return c.sum()
ds1.apply(test)
# Out:
# a               10
# b               22
# c    sudhanidghnam
# dtype: object

# %%
df2 = ds1[['a','b']]

# %%
df2
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6
# d  4  7

# %%
df2.applymap(lambda x:x**2)      #used on whole dataframe
# Out:
#     a   b
# a   1  16
# b   4  25
# c   9  36
# d  16  49

# %%
ds2=df.sort_values('c',ascending=False)

# %%
ds2
# Out:
#    b     c
# a
# 1  4  sudh
# 4  7   nam
# 3  6   dgh
# 2  5   ani

# %%
ds2.sort_index()
# Out:
#    b     c
# a
# 1  4  sudh
# 2  5   ani
# 3  6   dgh
# 4  7   nam

# %%
pd.set_option("display.max_colwidth",1000)     #used to display a min 500 words of data
df3 =pd.DataFrame({"Desc":["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.","this is my renew form","this my policy"]})

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc
# ...

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc
# ...

# %%
df3['len'] = df3['Desc'].apply(len)  # used to add new column to len

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc  \
# ...

# %%
df3['words'] = df3['Desc'].apply(lambda x:len(x.split()))   #used to find words in given data

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc  \
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    a  b     c
# 0  1  4  sudh
# 1  2  5   ani
# 2  3  6   dgh
# 3  4  7   nam

# %%
df['a'][0]     #to access element of[ column a and row 0]
# Out:
# 1

# %%
df
# Out:
#    a  b     c
# 0  1  4  sudh
# 1  2  5   ani
# 2  3  6   dgh
# 3  4  7   nam

# %%
df['a'].mean()      #to find mean of the colummn a elements
# Out:
# 2.5

# %%
df['a'].median()     #to find median of the colummn a elements
# Out:
# 2.5

# %%
df['a'].mode()        #to find mode of the colummn a elements
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df['a'].std()       #to find standard deviation of the colummn a elements
# Out:
# 1.2909944487358056

# %%
df['a'].sum()      #to find sum
# Out:
# 10

# %%
df['a'].min()    #to find minimum entries in a column
# Out:
# 1

# %%
df['a'].max()     # to find maximum entries in a a column
# Out:
# 4

# %%
df8=pd.DataFrame({'a':[3,4,5,2,1,3,4,5,6]})

# %%
df8
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df8['a'].rolling (window=2).mean()    #for windows =2 it takes value of current row and previous row and apply method mean for 0th row its previous element is NaN so its mean is NaN
# Out:
# 0    NaN
# 1    3.5
# 2    4.5
# 3    3.5
# 4    1.5
# 5    2.0
# 6    3.5
# 7    4.5
# 8    5.5
# Name: a, dtype: float64

# %%
df8['a'].rolling (window=1).mean()     #rolling function decide krta h apko kitna data lekr method apply krna for window =1 it takes row data 1 and find mean and put
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df8['a'].rolling (window=3).mean()      #for windows =3 it takes value of current row and previous 2 rows and apply method mean for 0th row its previous two elements are NaN so its mean is NaN
# Out:
# 0         NaN
# 1         NaN
# 2    4.000000
# 3    3.666667
# 4    2.666667
# 5    2.000000
# 6    2.666667
# 7    4.000000
# 8    5.000000
# Name: a, dtype: float64

# %%
df8
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
#python Pandas -Data Functionality

date=pd.date_range(start='2023-04-23',end='2023-06-23')    #generates all dates in provided range of start and end

# %%
date
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28',
#                '2023-05-29', '2023-05-30', '2023-05-31', '2023-06-01',
#                '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05',
#                '2023-06-06', '2023-06-07', '2023-06-08', '2023-06-09',
#                '2023-06-10', '2023-06-11', '2023-06-12', '2023-06-13',
# ...

# %%
df_date=pd.DataFrame({'date':date})

# %%
df_date
# Out:
#          date
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# ..        ...
# 57 2023-06-19
# 58 2023-06-20
# 59 2023-06-21
# 60 2023-06-22
# 61 2023-06-23
#
# [62 rows x 1 columns]

# %%
df9=pd.DataFrame({"date":['2023-06-23','2023-06-22','2023-06-21','2023-06-24']})

# %%
df9
# Out:
#          date
# 0  2023-06-23
# 1  2023-06-22
# 2  2023-06-21
# 3  2023-06-24

# %%
df9.dtypes
# Out:
# date    object
# dtype: object

# %%
df9['updated_date'] =pd.to_datetime(df9['date'])     #to update datatype object to datetime we use pd.to_datetime

# %%
df9
# Out:
#          date updated_date
# 0  2023-06-23   2023-06-23
# 1  2023-06-22   2023-06-22
# 2  2023-06-21   2023-06-21
# 3  2023-06-24   2023-06-24

# %%
df9.dtypes
# Out:
# date                    object
# updated_date    datetime64[ns]
# dtype: object

# %%
df9['year']=df9['updated_date'].dt.year    #to make separate column of year present in particular row we use dt.year

# %%
df9
# Out:
#          date updated_date  year
# 0  2023-06-23   2023-06-23  2023
# 1  2023-06-22   2023-06-22  2023
# 2  2023-06-21   2023-06-21  2023
# 3  2023-06-24   2023-06-24  2023

# %%
df9['month']=df9['updated_date'].dt.month   #same for month separate column

# %%
df9['day']=df9['updated_date'].dt.day

# %%
df9
# Out:
#          date updated_date  year  month  day
# 0  2023-06-23   2023-06-23  2023      6   23
# 1  2023-06-22   2023-06-22  2023      6   22
# 2  2023-06-21   2023-06-21  2023      6   21
# 3  2023-06-24   2023-06-24  2023      6   24

# %%
pd.Timedelta(days=1,hours=5,minutes =45)
# Out:
# Timedelta('1 days 05:45:00')

# %%
dt =pd.to_datetime('2023-06-20')   #to convert  string data to datetime

# %%
td=pd.Timedelta(days=1)    #to generate difference of one days or anytime

# %%
dt+td

       #this will show overall increase in date time according to time delta
# Out:
# Timestamp('2023-06-21 00:00:00')

# %%
#python Pandas -Categorical data

# %%
data=['sudh','krish','hitesh','kumar']

# %%
cat=pd.Categorical(data)     #return the no. of categories presennt inside data

# %%
cat
# Out:
# ['sudh', 'krish', 'hitesh', 'kumar']
# Categories (4, object): ['hitesh', 'krish', 'kumar', 'sudh']

# %%
cat.value_counts()    #this show to the counts to categories present in data
# Out:
# hitesh    1
# krish     1
# kumar     1
# sudh      1
# dtype: int64

# %%
#python Pandas -visualization

# %%
d=pd.Series([1,2,3,4,58,6,9])       #to provide series

# %%
d
d.plot()   #to plot series on axes where x is index and y has values inside series    draw linear graph
# Out:
# <Axes: >

# %%
df = pd.DataFrame({'a':[5,8,7,9,5],
                   'b':[8,9,7,6,5]})

# %%
df
# Out:
#    a  b
# 0  5  8
# 1  8  9
# 2  7  7
# 3  9  6
# 4  5  5

# %%
df.plot(x='a',y='b')
# Out:
# <Axes: xlabel='a'>

# %%
df.plot.scatter(x='a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
d=pd.Series([1,2,3,4,58,6,9])

# %%
d.plot.pie()
# Out:
# <Axes: >
